# %% [markdown]
# # Modeling and Evaluation

# %% [markdown]
# ## Objectives

# %% [markdown]
# * Fit a cluster model to group similar data

# %% [markdown]
# ## Inputs

# %% [markdown]
# * inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv

# %% [markdown]
# ## Outputs

# %% [markdown]
# * Cluster pipeline
# * Train Set
# * Cluster Description
# * Cluster Silhouette

# %% [markdown]
# # Change working directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/heritage-housing-issues/jupyter_notebooks'

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/heritage-housing-issues'

# %% [markdown]
# # Load Data

# %%
import numpy as np
import pandas as pd
df = pd.read_csv(f"inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv")
print(df.shape)
df.head(3)
# Out:
# (1460, 24)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# 0       196.0          61            5            7          856         0.0
# 1         0.0           0            8            6         1262         NaN
# 2       162.0          42            5            7          920         NaN
#
#    YearBuilt  YearRemodAdd  SalePrice
# 0       2003          2003     208500
# 1       1976          1976     181500
# 2       2001          2002     223500
#
# [3 rows x 24 columns]

# %% [markdown]
# # Cluster Pipeline

# %%
from sklearn.pipeline import Pipeline

from feature_engine.encoding import OrdinalEncoder
from feature_engine import transformation as vt
from feature_engine.selection import DropFeatures
from feature_engine.imputation import  MeanMedianImputer
from feature_engine.imputation import  CategoricalImputer
from feature_engine.imputation import  ArbitraryNumberImputer
from feature_engine.selection import SmartCorrelatedSelection

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

from sklearn.cluster import KMeans


def PipelineCluster():
    pipeline_base = Pipeline([
        ("DropFeatures", DropFeatures(features_to_drop=['EnclosedPorch', 'WoodDeckSF'])),
        ("ArbitraryNumberImputer", ArbitraryNumberImputer(arbitrary_number=0, variables=['MasVnrArea', '2ndFlrSF'])),
        ("CategoricalImputer", CategoricalImputer(imputation_method='missing', fill_value='Unf', variables=['GarageFinish', 'BsmtFinType1'])),
        ("MeanMedianImputer", MeanMedianImputer(imputation_method='median', variables=['LotFrontage', 'BedroomAbvGr', 'GarageYrBlt'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure','BsmtFinType1','GarageFinish','KitchenQual'])),

        ("YeoJohnsonTransformer", vt.YeoJohnsonTransformer(variables=['BsmtUnfSF', 'GarageArea'])),
        ("PowerTransformer", vt.PowerTransformer(variables = ['1stFlrSF','LotArea', 'GrLivArea'], exp=0.5)),

        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),

        ("scaler", StandardScaler()),

        ("PCA", PCA(n_components=50, random_state=0)),

        ("model", KMeans(n_clusters=50, random_state=0)),

    ])

    return pipeline_base

# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
pipeline_cluster = PipelineCluster()
pipeline_pca = Pipeline(pipeline_cluster.steps[:-2])
df_pca = pipeline_pca.fit_transform(df)

print(df_pca.shape,'\n', type(df_pca))
# Out:
# (1460, 17)
#  <class 'numpy.ndarray'>
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]

# %% [markdown]
# We will apply PCA separately to the scaled data using CI function

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

n_components = 10


def pca_components_analysis(df_pca, n_components):
    pca = PCA(n_components=n_components).fit(df_pca)
    x_PCA = pca.transform(df_pca)

    ComponentsList = ["Component " + str(number)
                      for number in range(n_components)]
    dfExplVarRatio = pd.DataFrame(
        data=np.round(100 * pca.explained_variance_ratio_, 3),
        index=ComponentsList,
        columns=['Explained Variance Ratio (%)'])

    dfExplVarRatio['Accumulated Variance'] = dfExplVarRatio['Explained Variance Ratio (%)'].cumsum(
    )

    PercentageOfDataExplained = dfExplVarRatio['Explained Variance Ratio (%)'].sum(
    )

    print(
        f"* The {n_components} components explain {round(PercentageOfDataExplained,2)}% of the data \n")
    plt.figure(figsize=(9, 6))
    sns.lineplot(data=dfExplVarRatio,  marker="o")
    plt.xticks(rotation=90)
    plt.yticks(np.arange(0, 110, 10))
    plt.show()


pca_components_analysis(df_pca=df_pca, n_components=n_components)
# Out:
# * The 10 components explain 85.35% of the data

# %% [markdown]
# We are looking to cover at least 95% of the data, let's increase the components

# %%
pca_components_analysis(df_pca=df_pca,n_components=14)
# Out:
# * The 14 components explain 97.28% of the data

# %% [markdown]
# Refit the pipeline with the updated components

# %%
def PipelineCluster():
    pipeline_base = Pipeline([
        ("DropFeatures", DropFeatures(features_to_drop=['EnclosedPorch', 'WoodDeckSF'])),
        ("ArbitraryNumberImputer", ArbitraryNumberImputer(arbitrary_number=0, variables=['MasVnrArea', '2ndFlrSF'])),
        ("CategoricalImputer", CategoricalImputer(imputation_method='missing', fill_value='Unf', variables=['GarageFinish', 'BsmtFinType1'])),
        ("MeanMedianImputer", MeanMedianImputer(imputation_method='median', variables=['LotFrontage', 'BedroomAbvGr', 'GarageYrBlt'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure','BsmtFinType1','GarageFinish','KitchenQual'])),

        ("YeoJohnsonTransformer", vt.YeoJohnsonTransformer(variables=['BsmtUnfSF', 'GarageArea'])),
        ("PowerTransformer", vt.PowerTransformer(variables = ['1stFlrSF','LotArea', 'GrLivArea'], exp=0.5)),

        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),

        ("scaler", StandardScaler()),

        ("PCA", PCA(n_components=14, random_state=0)),

        ("model", KMeans(n_clusters=50, random_state=0)),

    ])

    return pipeline_base

# %% [markdown]
# ## Elbow Method

# %% [markdown]
# We will use elbow method and silhouette score to determine how many clusters we need

# %%
pipeline_cluster = PipelineCluster()
pipeline_analysis = Pipeline(pipeline_cluster.steps[:-1])
df_analysis = pipeline_analysis.fit_transform(df)
# Out:
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]

# %%
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(KMeans(random_state=0), k=(1,11))
visualizer.fit(df_analysis) 
visualizer.show() 
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Silhouette Score

# %%
from yellowbrick.cluster import SilhouetteVisualizer

n_cluster_start, n_cluster_stop = 2, 8

print("=== Average Silhouette Score for different number of clusters ===")
visualizer = KElbowVisualizer(KMeans(random_state=0), k=(
    n_cluster_start, n_cluster_stop), metric='silhouette')
visualizer.fit(df_analysis)
visualizer.show()
plt.show()
print("\n")


for n_clusters in np.arange(start=n_cluster_start, stop=n_cluster_stop):

    print(f"=== Silhouette plot for {n_clusters} Clusters ===")
    visualizer = SilhouetteVisualizer(estimator=KMeans(n_clusters=n_clusters, random_state=0),
                                      colors='yellowbrick')
    visualizer.fit(df_analysis)
    visualizer.show()
    plt.show()
    print("\n")
# Out:
# === Average Silhouette Score for different number of clusters ===
# === Silhouette plot for 2 Clusters ===
# === Silhouette plot for 3 Clusters ===
# === Silhouette plot for 4 Clusters ===
# === Silhouette plot for 5 Clusters ===
# === Silhouette plot for 6 Clusters ===
# === Silhouette plot for 7 Clusters ===

# %% [markdown]
# We will pick the most optimal cluster

# %%
def PipelineCluster():
    pipeline_base = Pipeline([
        ("DropFeatures", DropFeatures(features_to_drop=['EnclosedPorch', 'WoodDeckSF'])),
        ("ArbitraryNumberImputer", ArbitraryNumberImputer(arbitrary_number=0, variables=['MasVnrArea', '2ndFlrSF'])),
        ("CategoricalImputer", CategoricalImputer(imputation_method='missing', fill_value='Unf', variables=['GarageFinish', 'BsmtFinType1'])),
        ("MeanMedianImputer", MeanMedianImputer(imputation_method='median', variables=['LotFrontage', 'BedroomAbvGr', 'GarageYrBlt'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure','BsmtFinType1','GarageFinish','KitchenQual'])),

        ("YeoJohnsonTransformer", vt.YeoJohnsonTransformer(variables=['BsmtUnfSF', 'GarageArea'])),
        ("PowerTransformer", vt.PowerTransformer(variables = ['1stFlrSF','LotArea', 'GrLivArea'], exp=0.5)),

        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),

        ("scaler", StandardScaler()),

        ("PCA", PCA(n_components=14, random_state=0)),

        ("model", KMeans(n_clusters=4, random_state=0)),

    ])

    return pipeline_base

# %% [markdown]
# # Fit Cluster Pipeline

# %%
X = df.copy()
print(X.shape)
X.head(3)
# Out:
# (1460, 24)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# 0       196.0          61            5            7          856         0.0
# 1         0.0           0            8            6         1262         NaN
# 2       162.0          42            5            7          920         NaN
#
#    YearBuilt  YearRemodAdd  SalePrice
# 0       2003          2003     208500
# 1       1976          1976     181500
# 2       2001          2002     223500
#
# [3 rows x 24 columns]

# %%
pipeline_cluster = PipelineCluster()
pipeline_cluster.fit(X)
# Out:
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# Pipeline(steps=[('DropFeatures',
#                  DropFeatures(features_to_drop=['EnclosedPorch',
#                                                 'WoodDeckSF'])),
#                 ('ArbitraryNumberImputer',
#                  ArbitraryNumberImputer(arbitrary_number=0,
#                                         variables=['MasVnrArea', '2ndFlrSF'])),
#                 ('CategoricalImputer',
#                  CategoricalImputer(fill_value='Unf',
#                                     variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('MeanMedianImputer',
#                  MeanMedianImputer(variable...
#                                                      'BsmtFinSF1',
#                                                      'BsmtFinType1',
#                                                      'BsmtUnfSF', 'GarageArea',
#                                                      'GarageFinish',
#                                                      'GarageYrBlt', 'GrLivArea',
#                                                      'KitchenQual', 'LotArea',
#                                                      'LotFrontage',
#                                                      'MasVnrArea',
#                                                      'OpenPorchSF',
#                                                      'OverallCond',
#                                                      'OverallQual',
#                                                      'TotalBsmtSF', 'YearBuilt',
#                                                      'YearRemodAdd',
#                                                      'SalePrice'])),
#                 ('scaler', StandardScaler()),
#                 ('PCA', PCA(n_components=14, random_state=0)),
#                 ('model', KMeans(n_clusters=4, random_state=0))])

# %% [markdown]
# # Add cluster predictions to dataset

# %% [markdown]
# We add a new column for clusters

# %%
X['Clusters'] = pipeline_cluster['model'].labels_
print(X.shape)
X.head(3)
# Out:
# (1460, 25)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  MasVnrArea  \
# 0        150            0.0         548          RFn  ...       196.0
# 1        284            NaN         460          RFn  ...         0.0
# 2        434            0.0         608          RFn  ...       162.0
#
#    OpenPorchSF OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  YearBuilt  \
# 0           61           5            7          856         0.0       2003
# 1            0           8            6         1262         NaN       1976
# 2           42           5            7          920         NaN       2001
#
#    YearRemodAdd  SalePrice  Clusters
# 0          2003     208500         0
# 1          1976     181500         1
# 2          2002     223500         0
#
# [3 rows x 25 columns]

# %%
print(f"* Clusters frequencies \n{ X['Clusters'].value_counts(normalize=True).to_frame().round(2)} \n\n")
X['Clusters'].value_counts().sort_values().plot(kind='bar')
plt.show()
# Out:
# * Clusters frequencies
#    Clusters
# 2      0.45
# 1      0.24
# 0      0.22
# 3      0.08

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_analysis[:, 0], y=df_analysis[:, 1],
                hue=X['Clusters'], palette='Set1', alpha=0.6)
plt.scatter(x=pipeline_cluster['model'].cluster_centers_[:, 0], y=pipeline_cluster['model'].cluster_centers_[:, 1],
            marker="x", s=169, linewidths=3, color="black")
plt.xlabel("PCA Component 0")
plt.ylabel("PCA Component 1")
plt.title("PCA Components colored by Clusters")
plt.show()

# %%
cluster_predictions_with_all_variables = X['Clusters']
cluster_predictions_with_all_variables
# Out:
# 0       0
# 1       1
# 2       0
# 3       2
# 4       1
#        ..
# 1455    0
# 1456    1
# 1457    0
# 1458    2
# 1459    2
# Name: Clusters, Length: 1460, dtype: int32

# %% [markdown]
# # Fit a classifier, where the target is cluster predictions

# %%
df_clf = X.copy()
print(df_clf.shape)
df_clf.head(3)
# Out:
# (1460, 25)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  MasVnrArea  \
# 0        150            0.0         548          RFn  ...       196.0
# 1        284            NaN         460          RFn  ...         0.0
# 2        434            0.0         608          RFn  ...       162.0
#
#    OpenPorchSF OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  YearBuilt  \
# 0           61           5            7          856         0.0       2003
# 1            0           8            6         1262         NaN       1976
# 2           42           5            7          920         NaN       2001
#
#    YearRemodAdd  SalePrice  Clusters
# 0          2003     208500         0
# 1          1976     181500         1
# 2          2002     223500         0
#
# [3 rows x 25 columns]

# %% [markdown]
# Split Train and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df_clf.drop(['Clusters'], axis=1),
    df_clf['Clusters'],
    test_size=0.33,
    random_state=0
)

print(X_train.shape, X_test.shape)
# Out:
# (978, 24) (482, 24)

# %% [markdown]
# Now we fit a classifier to clustertarget variable pipeline

# %%
from sklearn.feature_selection import SelectFromModel

from sklearn.ensemble import GradientBoostingClassifier

def PipelineClf():
    pipeline_base = Pipeline([
        ("DropFeatures", DropFeatures(features_to_drop=['EnclosedPorch', 'WoodDeckSF'])),
        ("ArbitraryNumberImputer", ArbitraryNumberImputer(arbitrary_number=0, variables=['MasVnrArea', '2ndFlrSF'])),
        ("CategoricalImputer", CategoricalImputer(imputation_method='missing', fill_value='Unf', variables=['GarageFinish', 'BsmtFinType1'])),
        ("MeanMedianImputer", MeanMedianImputer(imputation_method='median', variables=['LotFrontage', 'BedroomAbvGr', 'GarageYrBlt'])),
        ("OrdinalCategoricalEncoder", OrdinalEncoder(encoding_method='arbitrary',
                                                     variables=['BsmtExposure','BsmtFinType1','GarageFinish','KitchenQual'])),

        ("YeoJohnsonTransformer", vt.YeoJohnsonTransformer(variables=['BsmtUnfSF', 'GarageArea'])),
        ("PowerTransformer", vt.PowerTransformer(variables = ['1stFlrSF','LotArea', 'GrLivArea'], exp=0.5)),

        ("SmartCorrelatedSelection", SmartCorrelatedSelection(variables=None,
         method="spearman", threshold=0.6, selection_method="variance")),

        ("scaler", StandardScaler()),

        ("feat_selection", SelectFromModel(
            GradientBoostingClassifier(random_state=0))),

        ("model", GradientBoostingClassifier(random_state=0)),

    ])

    return pipeline_base

# %% [markdown]
# Fit train and test set

# %%
pipeline_clf_cluster = PipelineClf()
pipeline_clf_cluster.fit(X_train, y_train)
# Out:
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# /home/codeany/.local/lib/python3.8/site-packages/feature_engine/selection/smart_correlation_selection.py:271: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   f = X[feature_group].std().sort_values(ascending=False).index[0]
# Pipeline(steps=[('DropFeatures',
#                  DropFeatures(features_to_drop=['EnclosedPorch',
#                                                 'WoodDeckSF'])),
#                 ('ArbitraryNumberImputer',
#                  ArbitraryNumberImputer(arbitrary_number=0,
#                                         variables=['MasVnrArea', '2ndFlrSF'])),
#                 ('CategoricalImputer',
#                  CategoricalImputer(fill_value='Unf',
#                                     variables=['GarageFinish',
#                                                'BsmtFinType1'])),
#                 ('MeanMedianImputer',
#                  MeanMedianImputer(variable...
#                                                      'GarageFinish',
#                                                      'GarageYrBlt', 'GrLivArea',
#                                                      'KitchenQual', 'LotArea',
#                                                      'LotFrontage',
#                                                      'MasVnrArea',
#                                                      'OpenPorchSF',
#                                                      'OverallCond',
#                                                      'OverallQual',
#                                                      'TotalBsmtSF', 'YearBuilt',
#                                                      'YearRemodAdd',
#                                                      'SalePrice'])),
#                 ('scaler', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=GradientBoostingClassifier(random_state=0))),
#                 ('model', GradientBoostingClassifier(random_state=0))])

# %% [markdown]
# # Evaluate classifier performance

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, pipeline_clf_cluster.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       223
#            1       0.98      0.97      0.98       225
#            2       0.99      0.99      0.99       444
#            3       1.00      1.00      1.00        86
#
#     accuracy                           0.99       978
#    macro avg       0.99      0.99      0.99       978
# weighted avg       0.99      0.99      0.99       978

# %%
print(classification_report(y_test, pipeline_clf_cluster.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       105
#            1       0.91      0.80      0.85       123
#            2       0.88      0.91      0.90       216
#            3       0.73      0.92      0.81        38
#
#     accuracy                           0.87       482
#    macro avg       0.85      0.87      0.85       482
# weighted avg       0.87      0.87      0.87       482

# %% [markdown]
# # Assess the most important Features

# %%
from sklearn.inspection import permutation_importance

feature_importances = permutation_importance(
    pipeline_clf_cluster, X_test, y_test, n_repeats=10, random_state=42
)

features = X_train.columns
best_features = feature_importances.importances_mean

plt.bar(features, best_features)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Cluster Analysis

# %% [markdown]
# Using custom functions from CI to load tables and describe each variable

# %%
def DescriptionAllClusters(df, decimal_points=3):

    DescriptionAllClusters = pd.DataFrame(
        columns=df.drop(['Clusters'], axis=1).columns)
    # iterate on each cluster , calls Clusters_IndividualDescription()
    for cluster in df.sort_values(by='Clusters')['Clusters'].unique():

        EDA_ClusterSubset = df.query(
            f"Clusters == {cluster}").drop(['Clusters'], axis=1)
        ClusterDescription = Clusters_IndividualDescription(
            EDA_ClusterSubset, cluster, decimal_points)
        DescriptionAllClusters = DescriptionAllClusters.append(
            ClusterDescription)

    DescriptionAllClusters.set_index(['Cluster'], inplace=True)
    return DescriptionAllClusters

def Clusters_IndividualDescription(EDA_Cluster, cluster, decimal_points):

    ClustersDescription = pd.DataFrame(columns=EDA_Cluster.columns)

    for col in EDA_Cluster.columns:

        try:

            if EDA_Cluster[col].dtypes == 'object':

                top_frequencies = EDA_Cluster.dropna(
                    subset=[col])[[col]].value_counts(normalize=True).nlargest(n=3)
                Description = ''

                for x in range(len(top_frequencies)):
                    freq = top_frequencies.iloc[x]
                    category = top_frequencies.index[x][0]
                    CategoryPercentage = int(round(freq*100, 0))
                    statement = f"'{category}': {CategoryPercentage}% , "
                    Description = Description + statement

                ClustersDescription.at[0, col] = Description[:-2]

            elif EDA_Cluster[col].dtypes in ['float', 'int']:
                DescStats = EDA_Cluster.dropna(subset=[col])[[col]].describe()
                Q1 = round(DescStats.iloc[4, 0], decimal_points)
                Q3 = round(DescStats.iloc[6, 0], decimal_points)
                Description = f"{Q1} -- {Q3}"
                ClustersDescription.at[0, col] = Description

        except Exception as e:
            ClustersDescription.at[0, col] = 'Not available'
            print(
                f"** Error Exception: {e} - cluster {cluster}, variable {col}")

    ClustersDescription['Cluster'] = str(cluster)

    return ClustersDescription

# %%
import plotly.express as px

def cluster_distribution_per_variable(df, target):

    df_bar_plot = df.value_counts(["Clusters", target]).reset_index()
    df_bar_plot.columns = ['Clusters', target, 'Count']
    df_bar_plot[target] = df_bar_plot[target].astype('object')

    print(f"Clusters distribution across {target} levels")
    fig = px.bar(df_bar_plot, x='Clusters', y='Count',
                 color=target, width=800, height=500)
    fig.update_layout(xaxis=dict(tickmode='array',
                      tickvals=df['Clusters'].unique()))
    fig.show()

    df_relative = (df
                   .groupby(["Clusters", target])
                   .size()
                   .groupby(level=0)
                   .apply(lambda x:  100*x / x.sum())
                   .reset_index()
                   .sort_values(by=['Clusters'])
                   )
    df_relative.columns = ['Clusters', target, 'Relative Percentage (%)']

    print(f"Relative Percentage (%) of {target} in each cluster")
    fig = px.line(df_relative, x='Clusters', y='Relative Percentage (%)',
                  color=target, width=800, height=500)
    fig.update_layout(xaxis=dict(tickmode='array',
                      tickvals=df['Clusters'].unique()))
    fig.update_traces(mode='markers+lines')
    fig.show()

# %% [markdown]
# Save a copy of a cluster profile

# %%
df_cluster_profile = df_clf.copy()
print(df_cluster_profile.shape)
df_cluster_profile.head(3)
# Out:
# (1460, 25)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  MasVnrArea  \
# 0        150            0.0         548          RFn  ...       196.0
# 1        284            NaN         460          RFn  ...         0.0
# 2        434            0.0         608          RFn  ...       162.0
#
#    OpenPorchSF OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  YearBuilt  \
# 0           61           5            7          856         0.0       2003
# 1            0           8            6         1262         NaN       1976
# 2           42           5            7          920         NaN       2001
#
#    YearRemodAdd  SalePrice  Clusters
# 0          2003     208500         0
# 1          1976     181500         1
# 2          2002     223500         0
#
# [3 rows x 25 columns]

# %% [markdown]
# Cluster profile based on the best features

# %%
pd.set_option('display.max_colwidth', None)
clusters_profile = DescriptionAllClusters(df=pd.concat([df_cluster_profile], axis=1), decimal_points=0)
clusters_profile
# Out:
# /tmp/ipykernel_5535/3637392981.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_5535/3637392981.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_5535/3637392981.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
# /tmp/ipykernel_5535/3637392981.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DescriptionAllClusters = DescriptionAllClusters.append(
#                  1stFlrSF         2ndFlrSF BedroomAbvGr  \
# Cluster
# 0         814.0 -- 1156.0  750.0 -- 1037.0   3.0 -- 4.0
# 1        1211.0 -- 1578.0       0.0 -- 0.0   2.0 -- 3.0
# 2         832.0 -- 1130.0     0.0 -- 513.0   2.0 -- 3.0
# 3        1504.0 -- 1982.0     0.0 -- 880.0   2.0 -- 3.0
#
#                                BsmtExposure       BsmtFinSF1  \
# Cluster
# 0         'No': 77% , 'Av': 10% , 'Mn': 7%      0.0 -- 554.0
# 1        'No': 51% , 'Av': 28% , 'Gd': 13%      2.0 -- 917.0
# 2          'No': 73% , 'Av': 9% , 'Mn': 8%      0.0 -- 593.0
# 3        'Gd': 35% , 'No': 31% , 'Av': 26%   806.0 -- 1386.0
#
#                                   BsmtFinType1        BsmtUnfSF EnclosedPorch  \
# Cluster
# 0         'Unf': 44% , 'GLQ': 33% , 'ALQ': 9%    281.0 -- 847.0    0.0 -- 0.0
# 1        'GLQ': 51% , 'Unf': 23% , 'ALQ': 19%   307.0 -- 1286.0    0.0 -- 0.0
# 2        'Unf': 28% , 'BLQ': 18% , 'ALQ': 18%    162.0 -- 674.0    0.0 -- 0.0
# 3         'GLQ': 79% , 'Unf': 14% , 'ALQ': 5%    310.0 -- 870.0    0.0 -- 0.0
#
#              GarageArea                            GarageFinish  ...  \
# Cluster                                                          ...
# 0        434.0 -- 601.0   'RFn': 41% , 'Fin': 35% , 'Unf': 23%   ...
# 1        462.0 -- 602.0   'RFn': 50% , 'Fin': 27% , 'Unf': 22%   ...
# 2        252.0 -- 480.0  'Unf': 69% , 'RFn': 12% , 'None': 11%   ...
# 3        660.0 -- 843.0    'Fin': 75% , 'RFn': 23% , 'Unf': 3%   ...
#
#           LotFrontage      MasVnrArea    OpenPorchSF OverallCond OverallQual  \
# Cluster
# 0        63.0 -- 85.0    0.0 -- 232.0  32.0 -- 104.0  5.0 -- 6.0  6.0 -- 7.0
# 1        56.0 -- 80.0    0.0 -- 182.0    0.0 -- 70.0  5.0 -- 5.0  6.0 -- 7.0
# 2        54.0 -- 74.0      0.0 -- 0.0    0.0 -- 20.0  5.0 -- 7.0  5.0 -- 6.0
# 3        78.0 -- 99.0  204.0 -- 558.0  45.0 -- 120.0  5.0 -- 5.0  8.0 -- 9.0
#
#               TotalBsmtSF      WoodDeckSF         YearBuilt      YearRemodAdd  \
# Cluster
# 0         762.0 -- 1050.0    0.0 -- 144.0  1974.0 -- 2003.0  1991.0 -- 2004.0
# 1        1160.0 -- 1517.0    0.0 -- 143.0  1977.0 -- 2005.0  1983.0 -- 2006.0
# 2         691.0 -- 1030.0    0.0 -- 164.0  1930.0 -- 1966.0  1951.0 -- 1994.0
# 3        1499.0 -- 1958.0  171.0 -- 214.0  1998.0 -- 2007.0  2002.0 -- 2008.0
#
#                     SalePrice
# Cluster
# 0        174000.0 -- 237250.0
# 1        165000.0 -- 220000.0
# 2        109500.0 -- 144000.0
# 3        292308.0 -- 392983.0
#
# [4 rows x 24 columns]

# %%
df_cluster_vs_churn=  df_cluster_profile.copy()
df_cluster_vs_churn['Clusters'] = X['Clusters']
cluster_distribution_per_variable(df=df_cluster_profile, target='SalePrice')
# Out:
# Clusters distribution across SalePrice levels
# <div>                            <div id="06991523-1e65-4666-b6f7-335fbbf0c94f" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06991523-1e65-4666-b6f7-335fbbf0c94f")) {                    Plotly.newPlot(                        "06991523-1e65-4666-b6f7-335fbbf0c94f",                        [{"alignmentgroup": "True", "hovertemplate": "SalePrice=135000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "135000", "marker": {"color": "#636efa"}, "name": "135000", "offsetgroup": "135000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1], "xaxis": "x", "y": [15, 2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=140000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "140000", "marker": {"color": "#EF553B"}, "name": "140000", "offsetgroup": "140000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1, 0], "xaxis": "x", "y": [14, 5, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=110000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "110000", "marker": {"color": "#00cc96"}, "name": "110000", "offsetgroup": "110000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1], "xaxis": "x", "y": [12, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=115000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "115000", "marker": {"color": "#ab63fa"}, "name": "115000", "offsetgroup": "115000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2], "xaxis": "x", "y": [12], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=145000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "145000", "marker": {"color": "#FFA15A"}, "name": "145000", "offsetgroup": "145000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1, 0], "xaxis": "x", "y": [10, 3, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=139000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "139000", "marker": {"color": "#19d3f3"}, "name": "139000", "offsetgroup": "139000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 0], "xaxis": "x", "y": [10, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=100000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "100000", "marker": {"color": "#FF6692"}, "name": "100000", "offsetgroup": "100000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2], "xaxis": "x", "y": [9], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=127000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "127000", "marker": {"color": "#B6E880"}, "name": "127000", "offsetgroup": "127000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2], "xaxis": "x", "y": [9], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=125000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "125000", "marker": {"color": "#FF97FF"}, "name": "125000", "offsetgroup": "125000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1], "xaxis": "x", "y": [9, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "SalePrice=155000<br>Clusters=%{x}<br>Count=%{y}<extra></extra>", "legendgroup": "155000", "marker": {"color": "#FECB52"}, "name": "155000", "offsetgroup": "155000", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 1, 0], "xaxis": "x", "y": [8, 3, 3], "yaxis": "y"}, {"alignmentgroup": "Tr ...
# Relative Percentage (%) of SalePrice in each cluster
# <div>                            <div id="40a6c7ee-f8e7-42a7-8a9e-1ff9b55b7ef6" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40a6c7ee-f8e7-42a7-8a9e-1ff9b55b7ef6")) {                    Plotly.newPlot(                        "40a6c7ee-f8e7-42a7-8a9e-1ff9b55b7ef6",                        [{"hovertemplate": "SalePrice=104000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "104000", "line": {"color": "#636efa", "dash": "solid"}, "mode": "markers+lines", "name": "104000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.3048780487804878], "yaxis": "y"}, {"hovertemplate": "SalePrice=228000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "228000", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "markers+lines", "name": "228000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1], "xaxis": "x", "y": [0.3048780487804878, 0.28735632183908044], "yaxis": "y"}, {"hovertemplate": "SalePrice=228500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "228500", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "markers+lines", "name": "228500", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.6097560975609756], "yaxis": "y"}, {"hovertemplate": "SalePrice=229000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "229000", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "markers+lines", "name": "229000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.3048780487804878], "yaxis": "y"}, {"hovertemplate": "SalePrice=230000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "230000", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "markers+lines", "name": "230000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1, 2], "xaxis": "x", "y": [1.2195121951219512, 0.8620689655172413, 0.15151515151515152], "yaxis": "y"}, {"hovertemplate": "SalePrice=230500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "230500", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "markers+lines", "name": "230500", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.3048780487804878], "yaxis": "y"}, {"hovertemplate": "SalePrice=231500<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "231500", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "markers+lines", "name": "231500", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.6097560975609756], "yaxis": "y"}, {"hovertemplate": "SalePrice=233000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "233000", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "markers+lines", "name": "233000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.3048780487804878], "yaxis": "y"}, {"hovertemplate": "SalePrice=233230<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "233230", "line": {"color": "#FF97FF", "dash": "solid"}, "mode": "markers+lines", "name": "233230", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0], "xaxis": "x", "y": [0.3048780487804878], "yaxis": "y"}, {"hovertemplate": "SalePrice=234000<br>Clusters=%{x}<br>Relative Percentage (%)=%{y}<extra></extra>", "legendgroup": "234000", "line": {"color": "#FECB52", "dash": "solid"}, "mode": "markers+lines", "name": "234000", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0, 1], "xaxis": "x", "y": [0.30487804 ...
